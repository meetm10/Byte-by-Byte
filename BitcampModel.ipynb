# %%
from nltk import word_tokenize
import nltk
from nltk.util import ngrams
from nltk.corpus import stopwords
from collections import Counter
from nltk import sent_tokenize
import os
import pickle

# %%
def getDict(filename):
    filename = filename + '.txt'
    with open(filename, encoding="utf8") as file:
        text = file.read()
    senttokens = sent_tokenize(text)
    stop = set(stopwords.words('english'))
    dct = {}
    dct['TotalCount'] = 0
    for sent in senttokens:
        wordToken = word_tokenize(sent)
        wordToken = [token for token in wordToken if token.isalnum() and not token.isdigit()]
        for i in range(len(wordToken)):
            word = wordToken[i].lower()
            if word not in dct:
                if word not in stop and len(word) > 1:
                    dct['TotalCount'] += 1
                    dct[word] = 1
            else:
                dct['TotalCount'] += 1
                dct[word] += 1
            if wordToken[i] in stop or wordToken[i-1] in stop:
                continue
            if i != 0:
                bigram = wordToken[i-1].lower() + ' ' + wordToken[i].lower()
                if bigram not in dct:
                    dct[bigram] = 1
                else:
                    dct[bigram] += 1
    return dct
#     return sorted(dct.items(), key = lambda kv: kv[1], reverse = True)

# %%
def main():
    path = 'C:/Users/Deep/Hackathon'
    text_files = [f[:-4] for f in os.listdir(path) if f.endswith('.txt')]
    FinalDct = {}
    for file in text_files:
        FinalDct[file] = getDict(file)
    output = open('Final.pkl', 'wb')
    pickle.dump(FinalDct, output)
    return FinalDct

# %%
main()
# Out:
# {'Arrays': {'TotalCount': 658,
#   'computer': 1,
#   'in computer': 1,
#   'programming': 7,
#   'computer programming': 1,
#   'array': 33,
#   'set': 3,
#   'data': 23,
#   'elements': 19,
#   'data elements': 1,
#   'stored': 6,
#   'elements stored': 1,
#   'name': 1,
#   'arrays': 11,
#   'created': 2,
#   'hold': 1,
#   'type': 7,
#   'element': 25,
#   'individually': 1,
#   'assigned': 1,
#   'individually assigned': 1,
#   'read': 3,
#   'numbers': 3,
#   'characters': 4,
#   'numbers characters': 1,
#   'sentences': 1,
#   'characters sentences': 1,
#   'boolean': 2,
#   'sentences boolean': 1,
#   'values': 13,
#   'boolean values': 2,
#   'might': 3,
#   'arrays might': 1,
#   'store': 8,
#   'might store': 1,
#   'vertex': 1,
#   'store vertex': 1,
#   'vertex data': 1,
#   'complex': 1,
#   'shapes': 1,
#   'complex shapes': 1,
#   'recent': 1,
#   'shapes recent': 1,
#   'keystrokes': 1,
#   'recent keystrokes': 1,
#   'keyboard': 1,
#   'data read': 1,
#   'file': 4,
#   'instance': 1,
#   'for instance': 1,
#   'five': 3,
#   'store five': 1,
#   'integers': 1,
#   'five integers': 1,
#   'years': 1,
#   'date': 1,
#   'cincinnati': 1,
#   'reds': 1,
#   'cincinnati reds': 1,
#   'world': 1,
#   'series': 1,
#   'world series': 1,
#   'rather': 1,
#   'series rather': 1,
#   'defining': 1,
#   'defining five': 1,
#   'separate': 2,
#   'five separate': 1,
#   'variables': 1,
#   'separate variables': 1,
#   'let': 4,
#   'call': 1,
#   'dates': 1,
#   'array dates': 1,
#   'sequence': 2,
#   'array elements': 1,
#   'numbered': 1,
#   'starting': 2,
#   'numbered starting': 1,
#   'zero': 1,
#   'may': 1,
#   'seem': 2,
#   'may seem': 1,
#   'confusing': 1,
#   'seem confusing': 1,
#   'first': 8,
#   'important': 2,
#   'detail': 2,
#   'important detail': 1,
#   'many': 1,
#   'many programming': 1,
#   'languages': 2,
#   'programming languages': 2,
#   'the first': 2,
#   'first element': 6,
#   'position': 6,
#   'second': 5,
#   'the position': 1,
#   'determined': 1,
#   'offset': 3,
#   'start': 2,
#   'second element': 1,
#   'one': 4,
#   'offset one': 1,
#   'place': 1,
#   'one place': 1,
#   'beginning': 3,
#   'last': 5,
#   'the last': 1,
#   'last position': 1,
#   'calculated': 1,
#   'subtracting': 1,
#   'length': 4,
#   'array length': 2,
#   'example': 3,
#   'last element': 3,
#   'five elements': 1,
#   'make': 1,
#   'task': 2,
#   'much': 1,
#   'programming much': 1,
#   'easier': 1,
#   'much easier': 1,
#   'necessary': 1,
#   'use': 10,
#   'valuable': 1,
#   'structures': 3,
#   'valuable structures': 1,
#   'managing': 1,
#   'managing data': 1,
#   'begin': 1,
#   'points': 1,
#   'data points': 1,
#   'construct': 1,
#   'bar': 1,
#   'chart': 1,
#   'bar chart': 1,
#   'classified': 2,
#   'homogeneous': 1,
#   'homogeneous data': 1,
#   'data structures': 2,
#   'store elements': 2,
#   'store numbers': 1,
#   'strings': 1,
#   'numbers strings': 1,
#   'strings boolean': 1,
#   'true': 1,
#   'values true': 1,
#   'false': 1,
#   'false characters': 1,
#   'objects': 1,
#   'characters objects': 1,
#   'define': 3,
#   'must': 3,
#   'elements must': 2,
#   'mix': 1,
#   'different': 1,
#   'mix different': 1,
#   'types': 1,
#   'different types': 1,
#   'amazing': 1,
#   'the amazing': 1,
#   'power': 1,
#   'amazing power': 1,
#   'comes': 1,
#   'arrays comes': 1,
#   'efficiency': 2,
#   'access': 7,
#   'access values': 1,
#   'achieved': 1,
#   'thanks': 1,
#   'achieved thanks': 1,
#   'structure': 1,
#   'take': 1,
#   'look': 1,
#   'create': 5,
#   'assign': 2,
#   'variable': 3,
#   'size': 2,
#   'maximum': 1,
#   'number': 5,
#   'maximum number': 1,
#   'you use': 1,
#   'called': 4,
#   'index': 14,
#   'indices': 4,
#   'index indices': 1,
#   'plural': 1,
#   'value': 3,
#   'refers': 1,
#   'location': 1,
#   'see': 2,
#   'diagram': 2,
#   'referred': 1,
#   'using': 3,
#   'using index': 1,
#   'move': 3,
#   'right': 4,
#   'increases': 1,
#   'index increases': 1,
#   'space': 4,
#   'memory': 9,
#   'general': 1,
#   'the general': 1,
#   'syntax': 1,
#   'general syntax': 1,
#   'arrayvariable': 1,
#   'arrayvariable index': 1,
#   'index for': 1,
#   'for example': 2,
#   'example if': 1,
#   'myarray': 2,
#   'variable myarray': 1,
#   'want': 4,
#   'would': 2,
#   'would use': 1,
#   'use myarray': 1,
#   'myarray to': 1,
#   'insert': 1,
#   'to insert': 1,
#   'located': 5,
#   'elements located': 1,
#   'insertion': 1,
#   'site': 1,
#   'insertion site': 1,
#   'site one': 1,
#   'one index': 2,
#   'index element': 1,
#   'element b': 1,
#   'now let': 1,
#   'say': 1,
#   'delete': 4,
#   'maintain': 1,
#   'to maintain': 1,
#   'random': 2,
#   'random access': 2,
#   'able': 1,
#   'extremely': 2,
#   'index extremely': 1,
#   'fast': 1,
#   'extremely fast': 1,
#   'contiguous': 3,
#   'spaces': 2,
#   'contiguous spaces': 2,
#   'leave': 1,
#   'empty': 3,
#   'space empty': 1,
#   'come': 1,
#   'delete one': 1,
#   'left': 2,
#   'deletion': 1,
#   'efficient': 4,
#   'remove': 2,
#   'since': 1,
#   'need': 3,
#   'keep': 2,
#   'track': 1,
#   'keep track': 1,
#   'last index': 1,
#   'contains': 1,
#   'contains elements': 1,
#   'directly': 1,
#   'directly remove': 1,
#   'element using': 1,
#   'three': 1,
#   'options': 1,
#   'three options': 1,
#   'find': 3,
#   'array if': 1,
#   'know': 3,
#   'located use': 1,
#   'sorted': 3,
#   'algorithms': 2,
#   'use algorithms': 2,
#   'optimize': 2,
#   'search': 4,
#   'binary': 4,
#   'binary search': 2,
#   'every': 1,
#   'every element': 1,
#   'check': 2,
#   'current': 1,
#   'current element': 1,
#   'looking': 1,
#   'please': 1,
#   'please see': 1,
#   'diagrams': 1,
#   'in arrays': 1,
#   'powerful': 1,
#   'extremely powerful': 1,
#   'powerful data': 1,
#   'the type': 1,
#   'fixed': 2,
#   'defined': 1,
#   'allocated': 1,
#   'immediately': 1,
#   'allocated immediately': 1,
#   'their elements': 1,
#   'locations': 1,
#   'contiguous locations': 1,
#   'accessed': 1,
#   'efficiently': 1,
#   'efficiently random': 1,
#   'access o': 1,
#   'constant': 2,
#   'o constant': 1,
#   'time': 3,
#   'constant time': 2,
#   'time using': 1,
#   'using indices': 1,
#   'indices start': 1,
#   'like': 1,
#   'used': 3,
#   'inserting': 2,
#   'inserting elements': 1,
#   'middle': 2,
#   'involves': 2,
#   'array involves': 2,
#   'moving': 2,
#   'involves moving': 2,
#   'moving elements': 1,
#   'full': 1,
#   'creating': 1,
#   'full creating': 1,
#   'new': 2,
#   'larger': 1,
#   'new larger': 1,
#   'larger array': 1,
#   'end': 2,
#   'efficient constant': 1,
#   'time o': 1,
#   'removing': 2,
#   'removing elements': 1,
#   'avoid': 1,
#   'leaving': 1,
#   'avoid leaving': 1,
#   'empty space': 1,
#   'guarantees': 1,
#   'this guarantees': 1,
#   'to find': 1,
#   'entire': 1,
#   'entire array': 1,
#   'process': 2,
#   'considering': 1,
#   'before considering': 1,
#   'examples': 1,
#   'consider': 1,
#   'characteristics': 1,
#   'important characteristics': 1,
#   'indexing': 2,
#   'always': 1,
#   'we always': 1,
#   'refer': 3,
#   'always refer': 1,
#   'forth': 2,
#   'it might': 1,
#   'might seem': 1,
#   'natural': 1,
#   'second value': 1,
#   'advantages': 1,
#   'emerged': 1,
#   'convention': 1,
#   'convention used': 1,
#   'modern': 1,
#   'modern programming': 1,
#   'program': 10,
#   'code': 4,
#   'representation': 1,
#   'memory representation': 1,
#   'use new': 1,
#   'java': 1,
#   'array java': 1,
#   'reserves': 1,
#   'java reserves': 1,
#   'reserves space': 1,
#   'initializes': 1,
#   'this process': 1,
#   'called memory': 1,
#   'allocation': 1,
#   'memory allocation': 1,
#   'bounds': 1,
#   'checking': 1,
#   'bounds checking': 1,
#   'when programming': 1,
#   'careful': 1,
#   'responsibility': 1,
#   'legal': 1,
#   'use legal': 1,
#   'legal indices': 1,
#   'accessing': 1,
#   'array element': 1,
#   'setting': 1,
#   'setting array': 1,
#   'array values': 1,
#   'compile': 1,
#   'compile time': 1,
#   'small': 1,
#   'small number': 1,
#   'literal': 1,
#   'literal values': 1,
#   'initialize': 1,
#   'listing': 1,
#   'curly': 1,
#   'braces': 1,
#   'curly braces': 1,
#   'separated': 1,
#   'braces separated': 1,
#   'comma': 1,
#   'might use': 1,
#   'following': 1,
#   'following code': 1,
#   'processes': 1,
#   'playing': 1,
#   'processes playing': 1,
#   'cards': 1,
#   'playing cards': 1,
#   'previous': 1,
#   'section': 2,
#   'previous section': 1,
#   'asarray': 1,
#   'data asarray': 1,
#   'initializer': 1,
#   'asarray initializer': 1,
#   'initializer values': 1,
#   'thisapproachworks': 1,
#   'while thisapproachworks': 1,
#   'also': 1,
#   'creates': 1,
#   'also creates': 1,
#   'problems': 1,
#   'graph': 1,
#   'theparticular': 1,
#   'graph theparticular': 1,
#   'theparticular set': 1,
#   'raw': 1,
#   'raw data': 1,
#   'makes': 1,
#   'impossible': 1,
#   'reuse': 1,
#   'programfor': 1,
#   'sets': 1,
#   'data sets': 1,
#   'changing': 1,
#   'second changing': 1,
#   'data values': 2,
#   'later': 1,
#   'later use': 1,
#   'use would': 1,
#   'require': 1,
#   'would require': 1,
#   'repeated': 1,
#   'require repeated': 1,
#   'rewriting': 1,
#   'repeated rewriting': 1,
#   'recompiling': 1,
#   'theprogram': 1,
#   'unacceptably': 1,
#   'better': 1,
#   'unacceptably better': 1,
#   'approach': 2,
#   'better approach': 1,
#   'thisdata': 1,
#   'management': 1,
#   'thisdata management': 1,
#   'management task': 1,
#   'storing': 1,
#   'program storing': 1,
#   'adatafile': 1,
#   'program file': 1,
#   'designingthe': 1,
#   'designingthe program': 1,
#   'data file': 1,
#   'single': 1,
#   'single program': 1,
#   'multiple': 1,
#   'multiple data': 1,
#   'files': 5,
#   'data files': 1,
#   'changed': 1,
#   'saved': 1,
#   'kind': 1,
#   'data stored': 1,
#   'contain': 2,
#   'textual': 1,
#   'contain textual': 1,
#   'textual characters': 1,
#   'source': 1,
#   'source code': 1,
#   'programs': 1,
#   'entered': 1,
#   'numbers entered': 1,
#   'text': 3,
#   'editor': 1,
#   'text editor': 1,
#   'called text': 1,
#   'text files': 2,
#   'filesthat': 1,
#   'filesthat contain': 1,
#   'contain characters': 1,
#   'binary code': 1,
#   'compiled': 1,
#   'compiled program': 1,
#   'control': 1,
#   'codes': 1,
#   'control codes': 1,
#   'word': 1,
#   'processor': 1,
#   'word processor': 1,
#   'processor file': 1,
#   'called binary': 1,
#   'binary files': 1,
#   'this section': 1,
#   'discusses': 1,
#   'section discusses': 1,
#   'processing': 1,
#   'discusses processing': 1,
#   'scapabilities': 1,
#   'processing scapabilities': 1,
#   'readingand': 1,
#   'writing': 1,
#   'readingand writing': 1,
#   'writing text': 1},
#  'Divide and Conquer': {'TotalCount': 912,
#   'strategy': 2,
#   'solves': 1,
#   'strategy solves': 1,
#   'problem': 3,
#   'breaking': 1,
#   'subproblems': 7,
#   'smaller': 3,
#   'instances': 1,
#   'smaller instances': 1,
#   'type': 1,
#   'recursively': 5,
#   'solving': 2,
#   'recursively solving': 2,
#   'appropriately': 1,
#   'combining': 3,
#   'appropriately combining': 1,
#   'answers': 3,
#   'answers the': 1,
#   'real': 1,
#   'the real': 1,
#   'work': 2,
#   'real work': 1,
#   'done': 2,
#   'piecemeal': 1,
#   'done piecemeal': 1,
#   'three': 5,
#   'different': 3,
#   'three different': 1,
#   'places': 2,
#   'different places': 1,
#   'partitioning': 2,
#   'problems': 1,
#   'tail': 1,
#   'end': 3,
#   'tail end': 1,
#   'recursion': 4,
#   'small': 1,
#   'solved': 1,
#   'outright': 1,
#   'solved outright': 1,
#   'gluing': 1,
#   'together': 4,
#   'gluing together': 1,
#   'partial': 1,
#   'partial answers': 1,
#   'held': 1,
#   'held together': 1,
#   'coordinated': 1,
#   'algorithm': 6,
#   'core': 1,
#   'recursive': 4,
#   'core recursive': 1,
#   'structure': 1,
#   'recursive structure': 1,
#   'introductory': 1,
#   'example': 6,
#   'introductory example': 1,
#   'see': 3,
#   'technique': 2,
#   'yields': 2,
#   'technique yields': 1,
#   'new': 3,
#   'new algorithm': 1,
#   'multiplying': 1,
#   'numbers': 2,
#   'multiplying numbers': 1,
#   'one': 8,
#   'numbers one': 1,
#   'much': 1,
#   'efficient': 1,
#   'method': 1,
#   'learned': 1,
#   'elementary': 1,
#   'school': 1,
#   'elementary school': 1,
#   'algorithms': 2,
#   'often': 1,
#   'algorithms often': 1,
#   'follow': 1,
#   'often follow': 1,
#   'generic': 1,
#   'pattern': 1,
#   'generic pattern': 1,
#   'tackle': 1,
#   'size': 8,
#   'size n': 2,
#   'say': 1,
#   'solving say': 1,
#   'nd': 7,
#   'o nd': 5,
#   'time': 4,
#   'nd time': 1,
#   'multiplication': 1,
#   'multiplication algorithm': 1,
#   'running': 2,
#   'their running': 1,
#   'running time': 1,
#   'therefore': 2,
#   'captured': 1,
#   'equation': 1,
#   'equation t': 1,
#   't n': 1,
#   'n at': 1,
#   'at o': 1,
#   'next': 3,
#   'we next': 1,
#   'derive': 1,
#   'next derive': 1,
#   'solution': 1,
#   'general': 1,
#   'recurrence': 1,
#   'general recurrence': 1,
#   'longer': 1,
#   'solve': 1,
#   'explicitly': 1,
#   'instance': 1,
#   'new instance': 1,
#   'instance this': 1,
#   'single': 2,
#   'this single': 1,
#   'theorem': 2,
#   'single theorem': 1,
#   'tells': 1,
#   'theorem tells': 1,
#   'us': 2,
#   'tells us': 1,
#   'times': 3,
#   'running times': 1,
#   'procedures': 1,
#   'likely': 1,
#   'use': 4,
#   'proof': 1,
#   'prove': 1,
#   'to prove': 1,
#   'claim': 1,
#   'let': 1,
#   'claim let': 1,
#   'start': 2,
#   'assuming': 1,
#   'sake': 1,
#   'convenience': 1,
#   'power': 2,
#   'influence': 1,
#   'final': 2,
#   'bound': 1,
#   'final bound': 1,
#   'important': 3,
#   'multiplicative': 1,
#   'factor': 4,
#   'multiplicative factor': 1,
#   'away': 1,
#   'b away': 1,
#   'exercise': 4,
#   'b exercise': 1,
#   'allow': 1,
#   'allow us': 1,
#   'ignore': 1,
#   'rounding': 1,
#   'effect': 1,
#   'rounding effect': 1,
#   'notice': 3,
#   'next notice': 1,
#   'decreases': 1,
#   'subproblems decreases': 1,
#   'level': 3,
#   'reaches': 1,
#   'therefore reaches': 1,
#   'base': 4,
#   'case': 9,
#   'base case': 4,
#   'logb': 4,
#   'logb n': 3,
#   'levels': 1,
#   'n levels': 1,
#   'height': 1,
#   'tree': 2,
#   'recursion tree': 1,
#   'branching': 1,
#   'its branching': 1,
#   'branching factor': 1,
#   'kth': 1,
#   'kth level': 1,
#   'made': 1,
#   'figure': 7,
#   'size figure': 1,
#   'total': 2,
#   'the total': 1,
#   'total work': 1,
#   'work done': 1,
#   'ak': 1,
#   'ak o': 1,
#   'bnk': 1,
#   'o bnk': 1,
#   'bad': 2,
#   'nd bad': 2,
#   'bad k': 1,
#   'k as': 1,
#   'as k': 1,
#   'goes': 1,
#   'k goes': 1,
#   'root': 1,
#   'leaves': 1,
#   'form': 1,
#   'numbers form': 1,
#   'geometric': 1,
#   'series': 5,
#   'geometric series': 1,
#   'ratio': 4,
#   'finding': 1,
#   'sum': 3,
#   'notation': 1,
#   'easy': 2,
#   'easy exercise': 1,
#   'comes': 1,
#   'cases': 2,
#   'three cases': 1,
#   'the ratio': 3,
#   'less': 7,
#   'decreasing': 1,
#   'given': 2,
#   'first': 9,
#   'term': 2,
#   'first term': 1,
#   'term o': 2,
#   'greater': 6,
#   'the series': 1,
#   'increasing': 1,
#   'last': 2,
#   'last term': 1,
#   'nlogb': 2,
#   'o nlogb': 1,
#   'bad logb': 1,
#   'n nd': 1,
#   'balog': 1,
#   'nd balog': 1,
#   'logbbnn': 1,
#   'balog logbbnn': 1,
#   'alogb': 1,
#   'alogb n': 1,
#   'loga': 1,
#   'loga n': 1,
#   'n logb': 1,
#   'exactly': 1,
#   'log': 1,
#   'o log': 1,
#   'log n': 1,
#   'terms': 1,
#   'n terms': 1,
#   'equal': 3,
#   'these cases': 1,
#   'translate': 1,
#   'cases translate': 1,
#   'directly': 1,
#   'translate directly': 1,
#   'contingencies': 1,
#   'three contingencies': 1,
#   'statement': 3,
#   'theorem statement': 1,
#   'merge': 12,
#   'sort': 14,
#   'merge sort': 8,
#   'sort we': 1,
#   'turn': 1,
#   'attention': 1,
#   'using': 3,
#   'divide': 5,
#   'conquer': 2,
#   'conquer strategy': 1,
#   'way': 1,
#   'improve': 1,
#   'performance': 2,
#   'sorting': 4,
#   'sorting algorithms': 1,
#   'the first': 2,
#   'first algorithm': 1,
#   'study': 1,
#   'recursive algorithm': 1,
#   'continually': 1,
#   'splits': 2,
#   'continually splits': 1,
#   'list': 44,
#   'half': 5,
#   'empty': 1,
#   'item': 6,
#   'one item': 2,
#   'sorted': 17,
#   'definition': 1,
#   'split': 15,
#   'invoke': 1,
#   'recursively invoke': 1,
#   'halves': 6,
#   'two': 9,
#   'two halves': 3,
#   'fundamental': 1,
#   'operation': 4,
#   'fundamental operation': 1,
#   'called': 4,
#   'operation called': 1,
#   'performed': 1,
#   'merging': 3,
#   'process': 10,
#   'taking': 2,
#   'taking two': 1,
#   'two smaller': 2,
#   'smaller sorted': 2,
#   'lists': 5,
#   'sorted lists': 4,
#   'single sorted': 1,
#   'sorted new': 1,
#   'new list': 1,
#   'shows': 5,
#   'figure shows': 4,
#   'familiar': 1,
#   'familiar example': 1,
#   'example list': 2,
#   'mergesort': 7,
#   'simple': 1,
#   'simple lists': 1,
#   'merged': 2,
#   'back': 2,
#   'merged back': 1,
#   'back together': 1,
#   'the mergesort': 2,
#   'function': 11,
#   'mergesort function': 5,
#   'shown': 2,
#   'function shown': 2,
#   'activecode': 2,
#   'begins': 3,
#   'activecode begins': 1,
#   'asking': 1,
#   'question': 1,
#   'case question': 1,
#   'length': 5,
#   'already': 4,
#   'sorted list': 4,
#   'processing': 1,
#   'necessary': 1,
#   'hand': 1,
#   'python': 1,
#   'slice': 3,
#   'python slice': 1,
#   'slice operation': 1,
#   'extract': 1,
#   'left': 4,
#   'right': 4,
#   'right halves': 1,
#   'note': 3,
#   'may': 3,
#   'list may': 2,
#   'even': 1,
#   'number': 1,
#   'even number': 1,
#   'items': 13,
#   'matter': 1,
#   'lengths': 1,
#   'differ': 1,
#   'invoked': 2,
#   'left half': 1,
#   'right half': 1,
#   'lines': 2,
#   'half lines': 1,
#   'assumed': 1,
#   'rest': 1,
#   'the rest': 1,
#   'function lines': 1,
#   'responsible': 1,
#   'larger': 1,
#   'larger sorted': 1,
#   'merge operation': 2,
#   'operation places': 1,
#   'items back': 1,
#   'original': 2,
#   'original list': 2,
#   'alist': 1,
#   'list alist': 1,
#   'alist one': 1,
#   'repeatedly': 1,
#   'repeatedly taking': 1,
#   'smallest': 1,
#   'smallest item': 1,
#   'augmented': 1,
#   'print': 2,
#   'print statement': 2,
#   'line': 2,
#   'statement line': 2,
#   'show': 2,
#   'contents': 2,
#   'invocation': 1,
#   'also': 2,
#   'merging process': 1,
#   'transcript': 1,
#   'the transcript': 1,
#   'transcript shows': 1,
#   'result': 4,
#   'executing': 1,
#   'evenly': 1,
#   'divide evenly': 1,
#   'first split': 1,
#   'gives': 2,
#   'split gives': 1,
#   'second': 2,
#   'second gives': 1,
#   'splitting': 2,
#   'splitting process': 1,
#   'eventually': 3,
#   'process eventually': 1,
#   'eventually yields': 1,
#   'immediately': 1,
#   'immediately merged': 1,
#   'order': 3,
#   'in order': 3,
#   'analyze': 2,
#   'need': 3,
#   'consider': 2,
#   'distinct': 1,
#   'two distinct': 1,
#   'processes': 1,
#   'distinct processes': 1,
#   'make': 3,
#   'implementation': 2,
#   'we already': 1,
#   'computed': 1,
#   'already computed': 1,
#   'binary': 1,
#   'search': 1,
#   'binary search': 1,
#   'logn': 3,
#   'half logn': 1,
#   'logn times': 1,
#   'the second': 1,
#   'second process': 1,
#   'each item': 1,
#   'processed': 1,
#   'placed': 1,
#   'results': 1,
#   'requires': 2,
#   'n requires': 1,
#   'requires n': 1,
#   'operations': 3,
#   'n operations': 1,
#   'the result': 3,
#   'analysis': 1,
#   'logn splits': 1,
#   'costs': 1,
#   'costs n': 1,
#   'nlogn': 4,
#   'nlogn operations': 1,
#   'a merge': 1,
#   'o nlogn': 2,
#   'nlogn algorithm': 1,
#   'recall': 1,
#   'slicing': 2,
#   'operator': 2,
#   'slicing operator': 1,
#   'o k': 1,
#   'guarantee': 1,
#   'remove': 1,
#   'slice operator': 1,
#   'possible': 2,
#   'simply': 2,
#   'pass': 1,
#   'simply pass': 1,
#   'starting': 1,
#   'ending': 1,
#   'indices': 1,
#   'ending indices': 1,
#   'along': 1,
#   'indices along': 1,
#   'call': 2,
#   'recursive call': 1,
#   'leave': 2,
#   'we leave': 2,
#   'function requires': 1,
#   'extra': 1,
#   'requires extra': 1,
#   'space': 2,
#   'extra space': 1,
#   'hold': 1,
#   'extracted': 1,
#   'slicing operations': 1,
#   'additional': 3,
#   'this additional': 1,
#   'additional space': 1,
#   'critical': 1,
#   'critical factor': 1,
#   'large': 2,
#   'problematic': 1,
#   'sort problematic': 1,
#   'working': 1,
#   'data': 1,
#   'large data': 1,
#   'sets': 1,
#   'data sets': 1,
#   'quicksort': 3,
#   'quicksort the': 1,
#   'quick': 4,
#   'the quick': 1,
#   'quick sort': 4,
#   'uses': 1,
#   'sort uses': 1,
#   'uses divide': 1,
#   'gain': 1,
#   'advantages': 1,
#   'using additional': 1,
#   'storage': 1,
#   'additional storage': 1,
#   'however': 1,
#   'divided': 2,
#   'happens': 1,
#   'diminished': 1,
#   'a quick': 1,
#   'sort first': 1,
#   'selects': 1,
#   'first selects': 1,
#   'value': 24,
#   'pivot': 19,
#   'pivot value': 19,
#   'although': 1,
#   'many': 1,
#   'many different': 1,
#   'ways': 2,
#   'different ways': 2,
#   'choose': 4,
#   'simply use': 1,
#   'first item': 2,
#   'role': 1,
#   'the role': 1,
#   'assist': 1,
#   'actual': 1,
#   'the actual': 1,
#   'position': 5,
#   'actual position': 1,
#   'belongs': 1,
#   'value belongs': 1,
#   'final sorted': 1,
#   'commonly': 1,
#   'list commonly': 1,
#   'commonly called': 1,
#   'point': 12,
#   'split point': 10,
#   'used': 2,
#   'subsequent': 1,
#   'calls': 1,
#   'subsequent calls': 1,
#   'serve': 1,
#   'first pivot': 1,
#   'since': 1,
#   'looked': 1,
#   'times already': 1,
#   'know': 1,
#   'eventually end': 1,
#   'currently': 1,
#   'position currently': 1,
#   'holding': 1,
#   'currently holding': 1,
#   'partition': 4,
#   'the partition': 2,
#   'partition process': 2,
#   'happen': 1,
#   'happen next': 1,
#   'find': 3,
#   'move': 2,
#   'time move': 1,
#   'appropriate': 1,
#   'side': 2,
#   'appropriate side': 1,
#   'either': 1,
#   'list either': 1,
#   'either less': 1,
#   'partitioning begins': 1,
#   'locating': 1,
#   'locating two': 1,
#   'two position': 1,
#   'leftmark': 3,
#   'beginning': 1,
#   'remaining': 1,
#   'remaining items': 1,
#   'positions': 1,
#   'list positions': 1,
#   'goal': 1,
#   'the goal': 1,
#   'move items': 1,
#   'wrong': 1,
#   'wrong side': 1,
#   'respect': 2,
#   'converging': 1,
#   'also converging': 1,
#   'locate': 2,
#   'begin': 2,
#   'we begin': 1,
#   'incrementing': 1,
#   'incrementing leftmark': 1,
#   'decrement': 1,
#   'rightmark': 3,
#   'decrement rightmark': 1,
#   'discovered': 1,
#   'discovered two': 1,
#   'two items': 2,
#   'place': 2,
#   'eventual': 1,
#   'eventual split': 1,
#   'occurs': 2,
#   'exchange': 1,
#   'repeat': 1,
#   'becomes': 1,
#   'rightmark becomes': 1,
#   'becomes less': 1,
#   'stop': 1,
#   'the position': 1,
#   'the pivot': 1,
#   'exchanged': 1,
#   'place figure': 1,
#   'addition': 2,
#   'in addition': 2,
#   'the list': 1,
#   'invoked recursively': 1,
#   'the quicksort': 1,
#   'quicksort function': 2,
#   'invokes': 1,
#   'activecode invokes': 1,
#   'recursive function': 1,
#   'quicksorthelper': 2,
#   'function quicksorthelper': 1,
#   'quicksorthelper begins': 1,
#   'already sorted': 1,
#   'partitioned': 1,
#   'recursively sorted': 1,
#   'partition function': 1,
#   'implements': 1,
#   'function implements': 1,
#   'described': 1,
#   'process described': 1,
#   'earlier': 2,
#   'described earlier': 1,
#   'to analyze': 1,
#   'function note': 1,
#   'length n': 1,
#   'always': 1,
#   'partition always': 1,
#   'always occurs': 1,
#   'middle': 5,
#   'divisions': 1,
#   'logn divisions': 1,
#   'n items': 2,
#   'needs': 1,
#   'items needs': 1,
#   'checked': 1,
#   'memory': 1,
#   'additional memory': 1,
#   'sort process': 1,
#   'unfortunately': 1,
#   'worst': 1,
#   'worst case': 1,
#   'points': 1,
#   'split points': 1,
#   'points may': 1,
#   'skewed': 1,
#   'leaving': 1,
#   'right leaving': 1,
#   'uneven': 2,
#   'division': 2,
#   'uneven division': 2,
#   'case sorting': 1,
#   'divides': 2,
#   'items divides': 1,
#   'then sorting': 1,
#   'n2': 1,
#   'o n2': 1,
#   'overhead': 1,
#   'mentioned': 1,
#   'recursion mentioned': 1,
#   'mentioned earlier': 1,
#   'particular': 1,
#   'in particular': 1,
#   'attempt': 1,
#   'alleviate': 1,
#   'potential': 1,
#   'technique called': 1,
#   'median': 3,
#   'called median': 1,
#   'to choose': 1,
#   'element': 1,
#   'last element': 1,
#   'pick': 1,
#   'now pick': 1,
#   'median value': 1,
#   'course': 1,
#   'originally': 1,
#   'used originally': 1,
#   'idea': 1,
#   'the idea': 1,
#   'belong': 1,
#   'toward': 1,
#   'belong toward': 1,
#   'better': 1,
#   'better middle': 1,
#   'middle value': 1,
#   'particularly': 1,
#   'useful': 1,
#   'particularly useful': 1,
#   'somewhat': 1,
#   'somewhat sorted': 1,
#   'selection': 1,
#   'value selection': 1},
#  'Graphs': {'TotalCount': 1673,
#   'graphs': 76,
#   'definition': 7,
#   'graphs definition': 5,
#   'applications': 9,
#   'definition applications': 5,
#   'representation': 12,
#   'applications representation': 5,
#   'representation graphs': 1,
#   'relations': 1,
#   'relations graphs': 1,
#   'sometimes': 3,
#   'graphs sometimes': 1,
#   'referred': 2,
#   'sometimes referred': 1,
#   'networks': 8,
#   'offer': 1,
#   'networks offer': 1,
#   'way': 3,
#   'expressing': 1,
#   'relationships': 10,
#   'expressing relationships': 1,
#   'pairs': 4,
#   'items': 3,
#   'one': 10,
#   'important': 6,
#   'abstractions': 4,
#   'important abstractions': 1,
#   'computer': 3,
#   'science': 1,
#   'computer science': 1,
#   'question': 6,
#   'makes': 4,
#   'what makes': 2,
#   'makes graphs': 2,
#   'special': 4,
#   'graphs special': 1,
#   'represent': 28,
#   'represent relationships': 1,
#   'might': 4,
#   'discover': 1,
#   'discovered': 1,
#   'discover discovered': 1,
#   'already': 1,
#   'discovered already': 1,
#   'already relationships': 1,
#   'things': 2,
#   'abstract': 2,
#   'concrete': 1,
#   'mathematical': 4,
#   'concrete mathematical': 1,
#   'objects': 2,
#   'mathematical objects': 1,
#   'objects things': 1,
#   'events': 1,
#   'things events': 1,
#   'people': 1,
#   'events people': 1,
#   'everything': 1,
#   'makes everything': 1,
#   'interesting': 8,
#   'everything interesting': 1,
#   'considered': 2,
#   'isolation': 3,
#   'hardly': 1,
#   'isolation hardly': 1,
#   'anything': 2,
#   'hardly anything': 1,
#   'example': 16,
#   'for example': 5,
#   'example considered': 1,
#   'would': 3,
#   'nothing': 1,
#   'nothing interesting': 1,
#   'person': 3,
#   'start': 2,
#   'considering': 1,
#   'start considering': 1,
#   'world': 1,
#   'around': 1,
#   'world around': 1,
#   'becomes': 1,
#   'person becomes': 1,
#   'becomes interesting': 1,
#   'challenge': 1,
#   'try': 1,
#   'find': 5,
#   'something': 1,
#   'find something': 1,
#   'something interesting': 1,
#   'difficulty': 1,
#   'even': 2,
#   'biological': 3,
#   'level': 1,
#   'biological level': 1,
#   'cells': 5,
#   'molecules': 1,
#   'cells molecules': 1,
#   'mechanisms': 1,
#   'biological mechanisms': 1,
#   'trees': 2,
#   'captures': 1,
#   'trees captures': 1,
#   'captures relationships': 1,
#   'tree': 10,
#   'also': 5,
#   'also represent': 1,
#   'certain': 2,
#   'represent certain': 1,
#   'certain relationships': 1,
#   'expressive': 1,
#   'tree tree': 1,
#   'cycles': 5,
#   'multiple': 2,
#   'paths': 6,
#   'multiple paths': 1,
#   'two': 3,
#   'nodes': 3,
#   'two nodes': 1,
#   'mean': 3,
#   'relationship': 2,
#   'essentially': 1,
#   'essentially anything': 1,
#   'abstractly': 1,
#   'represent abstractly': 1,
#   'figure': 5,
#   'friendship': 1,
#   'figure friendship': 1,
#   'relation': 7,
#   'friendship relation': 1,
#   'alice': 2,
#   'relation alice': 1,
#   'bob': 4,
#   'alice bob': 2,
#   'bob bob': 1,
#   'bob alice': 1,
#   'michel': 4,
#   'bob michel': 1,
#   'michel michel': 2,
#   'michel bob': 1,
#   'josefa': 2,
#   'bob josefa': 1,
#   'josefa michel': 1,
#   'michel josefa': 1,
#   'graph': 54,
#   'notion': 1,
#   'mathematical notion': 1,
#   'a relation': 1,
#   'defined': 1,
#   'subset': 1,
#   'cartesian': 1,
#   'product': 1,
#   'cartesian product': 1,
#   'sets': 12,
#   'two sets': 1,
#   'cool': 1,
#   'mathematical relation': 2,
#   'see': 2,
#   'to represent': 2,
#   'construct': 1,
#   'whose': 1,
#   'graph whose': 1,
#   'vertices': 44,
#   'whose vertices': 1,
#   'vertices represent': 8,
#   'domain': 2,
#   'range': 1,
#   'connect': 1,
#   'edges': 33,
#   'described': 1,
#   'shows': 1,
#   'figure shows': 1,
#   'clarify': 1,
#   'momentarily': 1,
#   'edges momentarily': 1,
#   'defining': 2,
#   'defining graphs': 2,
#   'graphs to': 1,
#   'able': 1,
#   'use': 11,
#   'use graph': 1,
#   'graph abstractions': 1,
#   'become': 3,
#   'acquainted': 1,
#   'become acquainted': 1,
#   'terminology': 3,
#   'section': 1,
#   'define': 1,
#   'define graphs': 1,
#   'summarize': 1,
#   'directed': 26,
#   'directed graphs': 6,
#   'formally': 3,
#   'directed graph': 13,
#   'digraph': 2,
#   'pair': 7,
#   'pair g': 2,
#   'g v': 7,
#   'v a': 1,
#   'set': 20,
#   'a v': 2,
#   'v v': 10,
#   'directed edges': 3,
#   'arcs': 1,
#   'arc': 7,
#   'each arc': 1,
#   'ordered': 1,
#   'ordered pair': 1,
#   'pair e': 2,
#   'e u': 2,
#   'u v': 17,
#   'a digraph': 1,
#   'u u': 2,
#   'graphs represent': 2,
#   'asymmetric': 1,
#   'represent asymmetric': 1,
#   'asymmetric relationships': 1,
#   'web': 4,
#   'page': 2,
#   'web page': 2,
#   'points': 2,
#   'page points': 1,
#   'necessarily': 1,
#   'point': 2,
#   'necessarily point': 1,
#   'back': 1,
#   'point back': 1,
#   'graphs an': 1,
#   'an example': 2,
#   'undirected': 18,
#   'an undirected': 4,
#   'undirected graph': 11,
#   'vertices1': 1,
#   'vertices1 figure': 1,
#   'figure example': 1,
#   'example graphs': 1,
#   'undirected graphs': 5,
#   'v e': 8,
#   'e σ': 1,
#   'case': 2,
#   'edge': 19,
#   'unordered': 1,
#   'unordered pair': 1,
#   'equivalently': 2,
#   'definition question': 1,
#   'think': 1,
#   'represent undirected': 3,
#   'digraphs': 1,
#   'sense': 1,
#   'general': 2,
#   'since': 5,
#   'graphs since': 2,
#   'easily': 1,
#   'easily represent': 1,
#   'placing': 1,
#   'direction': 2,
#   'indeed': 2,
#   'often': 7,
#   'data': 7,
#   'structures': 3,
#   'data structures': 2,
#   'come': 1,
#   'graphs come': 1,
#   'lot': 1,
#   'fortunately': 1,
#   'intuitive': 1,
#   'understand': 2,
#   'concept': 1,
#   'talk': 3,
#   'associated': 1,
#   'data associated': 1,
#   'weights': 3,
#   'chapter': 8,
#   'in chapter': 1,
#   'weighted': 1,
#   'weighted graphs': 1,
#   'distance': 3,
#   'capacity': 1,
#   'strength': 1,
#   'connection': 2,
#   'neighbors': 17,
#   'vertex': 25,
#   'a vertex': 2,
#   'vertex u': 4,
#   'neighbor': 2,
#   'adjacent': 3,
#   'equivalently adjacent': 1,
#   'vertex v': 9,
#   'graph g': 6,
#   'edge u': 4,
#   'v for': 1,
#   'v u': 3,
#   'neighborhood': 4,
#   'u neighborhood': 1,
#   'ntt': 5,
#   'neighborhood ntt': 1,
#   'ntt v': 3,
#   'v ntt': 1,
#   'use n': 1,
#   'n v': 2,
#   'indicate': 3,
#   'tt': 2,
#   'tt tt': 1,
#   'use ntt': 1,
#   'the neighborhood': 1,
#   'vertices u': 1,
#   'union': 1,
#   'neighborhoods': 1,
#   'ntt u': 1,
#   'u ntt': 1,
#   'degree': 4,
#   'the degree': 1,
#   'dtt': 7,
#   'degree dtt': 1,
#   'dtt v': 7,
#   'size': 1,
#   'neighborhood v': 1,
#   'for directed': 2,
#   'use v': 1,
#   'drop': 2,
#   'subscript': 1,
#   'subscript g': 1,
#   'clear': 1,
#   'context': 1,
#   'talking': 1,
#   'path': 13,
#   'a path': 2,
#   'sequence': 5,
#   'adjacent vertices': 1,
#   'more formally': 1,
#   'e paths': 1,
#   'paths g': 1,
#   'g p': 1,
#   'p v': 1,
#   'pi': 1,
#   'p pi': 1,
#   'pi e': 1,
#   'indicates': 1,
#   'v indicates': 1,
#   'positive': 1,
#   'length': 8,
#   'positive length': 1,
#   'sequences': 5,
#   'length sequences': 1,
#   'allowing': 1,
#   'vertices allowing': 1,
#   'repeats': 1,
#   'the length': 1,
#   'less': 2,
#   'one less': 1,
#   'number': 4,
#   'finite': 3,
#   'finite graph': 1,
#   'infinite': 1,
#   'infinite length': 1,
#   'simple': 5,
#   'a simple': 2,
#   'simple path': 1,
#   'repeated': 3,
#   'repeated vertices': 3,
#   'please': 1,
#   'please see': 1,
#   'remark': 1,
#   'however': 2,
#   'reachability': 1,
#   'connectivity': 1,
#   'reachable': 4,
#   'starting': 1,
#   'path starting': 1,
#   'ending': 1,
#   'we use': 1,
#   'rtt': 1,
#   'use rtt': 1,
#   'rtt v': 1,
#   'vertices reachable': 1,
#   'connected': 3,
#   'a directed': 3,
#   'strongly': 1,
#   'strongly connected': 1,
#   'cycle': 5,
#   'starts': 2,
#   'ends': 2,
#   'a cycle': 1,
#   'length one': 1,
#   'self': 2,
#   'loop': 1,
#   'self loop': 1,
#   'simple cycle': 2,
#   'end': 1,
#   'end vertices': 1,
#   'first': 3,
#   'last': 1,
#   'least': 3,
#   'three': 1,
#   'least three': 1,
#   'course': 1,
#   'exclusively': 1,
#   'exclusively talk': 1,
#   'simple cycles': 1,
#   'hence': 1,
#   'often drop': 1,
#   'drop simple': 1,
#   'forests': 1,
#   'forest': 3,
#   'called': 5,
#   'converted': 1,
#   'applications of': 1,
#   'of graphs': 1,
#   'graphs edges': 1,
#   'undirected forest': 1,
#   'rooted': 1,
#   'a rooted': 1,
#   'rooted tree': 1,
#   'one vertex': 1,
#   'designated': 1,
#   'vertex designated': 1,
#   'root': 3,
#   'typically': 2,
#   'toward': 1,
#   'directed toward': 1,
#   'away': 2,
#   'acyclic': 2,
#   'directed acyclic': 2,
#   'acyclic graphs': 1,
#   'acyclic graph': 1,
#   'dag': 1,
#   'graph dag': 1,
#   'the distance': 1,
#   'δtt': 2,
#   'distance δtt': 1,
#   'δtt u': 2,
#   'shortest': 3,
#   'shortest path': 3,
#   'minimum': 1,
#   'path minimum': 1,
#   'minimum number': 1,
#   'also referred': 1,
#   'path length': 2,
#   'diameter': 2,
#   'the diameter': 1,
#   'maximum': 1,
#   'maximum shortest': 1,
#   'diam': 1,
#   'vertices diam': 1,
#   'diam g': 1,
#   'max': 1,
#   'g max': 1,
#   'max δtt': 1,
#   'multigraphs': 1,
#   'sometimes graphs': 1,
#   'allow': 5,
#   'graphs allow': 1,
#   'allow multiple': 1,
#   'multiple edges': 1,
#   'vertices called': 1,
#   'couple': 1,
#   'algorithms': 4,
#   'couple algorithms': 1,
#   'convenience': 1,
#   'sparse': 5,
#   'dense': 2,
#   'dense graphs': 1,
#   'convention': 1,
#   'by convention': 1,
#   'following': 3,
#   'definitions': 1,
#   'following definitions': 1,
#   'definitions n': 1,
#   'note': 4,
#   'n2': 5,
#   'n2 edges': 1,
#   'including': 1,
#   'edges including': 1,
#   'including self': 1,
#   'loops': 1,
#   'self loops': 1,
#   'n n': 3,
#   'informally': 1,
#   'we informally': 1,
#   'say': 1,
#   'informally say': 1,
#   'otherwise': 2,
#   'dense otherwise': 1,
#   'applications graphs': 1,
#   'sparse often': 1,
#   'handful': 1,
#   'per': 1,
#   'neighbors per': 1,
#   'per vertex': 1,
#   'averaged': 1,
#   'across': 1,
#   'averaged across': 1,
#   'across vertices': 1,
#   'although': 2,
#   'vertices although': 1,
#   'could': 2,
#   'vertices could': 1,
#   'high': 1,
#   'high degree': 1,
#   'therefore': 2,
#   'emphasis': 1,
#   'design': 1,
#   'graph algorithms': 1,
#   'book': 2,
#   'work': 13,
#   'well': 3,
#   'work well': 1,
#   'sparse graphs': 1,
#   'powerful': 1,
#   'powerful abstractions': 1,
#   'abstractions graphs': 1,
#   'modeling': 1,
#   'modeling data': 1,
#   'fact': 2,
#   'in fact': 1,
#   'many': 6,
#   'fact many': 1,
#   'problems': 2,
#   'many problems': 1,
#   'reduced': 2,
#   'known': 2,
#   'known graph': 1,
#   'graph problems': 1,
#   'outline': 1,
#   'many applications': 1,
#   'social': 2,
#   'network': 5,
#   'social network': 1,
#   'network graphs': 1,
#   'tweet': 2,
#   'knows': 1,
#   'communicates': 1,
#   'influences': 1,
#   'social structures': 1,
#   'twitter': 1,
#   'twitter graph': 1,
#   'follows': 1,
#   'used': 18,
#   'determine': 5,
#   'information': 2,
#   'flows': 1,
#   'information flows': 1,
#   'topics': 1,
#   'topics become': 1,
#   'hot': 1,
#   'become hot': 1,
#   'communities': 1,
#   'develop': 1,
#   'communities develop': 1,
#   'good': 2,
#   'match': 1,
#   'good match': 1,
#   'transportation': 3,
#   'transportation networks': 2,
#   'road': 2,
#   'in road': 1,
#   'road networks': 1,
#   'networks vertices': 2,
#   'intersections': 1,
#   'segments': 1,
#   'road segments': 1,
#   'public': 2,
#   'public transportation': 1,
#   'stops': 1,
#   'links': 1,
#   'such networks': 1,
#   'map': 6,
#   'many map': 1,
#   'programs': 1,
#   'map programs': 1,
#   'google': 1,
#   'maps': 4,
#   'google maps': 1,
#   'bing': 1,
#   'maps bing': 1,
#   'bing maps': 1,
#   'apple': 1,
#   'ios': 1,
#   'apple ios': 1,
#   'ios maps': 1,
#   'maps well': 1,
#   'perhaps': 1,
#   'well perhaps': 1,
#   'without': 1,
#   'perhaps without': 1,
#   'transport': 1,
#   'public transport': 1,
#   'best': 3,
#   'routes': 1,
#   'best routes': 1,
#   'locations': 1,
#   'also used': 2,
#   'studying': 2,
#   'traffic': 3,
#   'studying traffic': 1,
#   'patterns': 1,
#   'traffic patterns': 1,
#   'patterns traffic': 1,
#   'light': 1,
#   'traffic light': 1,
#   'timings': 1,
#   'light timings': 1,
#   'aspects': 1,
#   'many aspects': 1,
#   'utility': 1,
#   'utility graphs': 1,
#   'power': 1,
#   'the power': 1,
#   'grid': 1,
#   'power grid': 1,
#   'internet': 2,
#   'water': 1,
#   'water network': 1,
#   'examples': 1,
#   'represent connection': 1,
#   'connection points': 1,
#   'wires': 1,
#   'pipes': 1,
#   'analyzing': 3,
#   'properties': 1,
#   'analyzing properties': 1,
#   'understanding': 2,
#   'ity': 1,
#   'utilities': 1,
#   'failure': 1,
#   'attack': 1,
#   'minimizing': 1,
#   'costs': 3,
#   'build': 1,
#   'infrastructure': 1,
#   'build infrastructure': 1,
#   'matches': 2,
#   'required': 1,
#   'matches required': 1,
#   'demands': 1,
#   'required demands': 1,
#   'document': 1,
#   'link': 4,
#   'document link': 1,
#   'link graphs': 2,
#   'the best': 1,
#   'best known': 1,
#   'known example': 1,
#   'link graph': 1,
#   'hyperlink': 1,
#   'directed edge': 1,
#   'analyze': 2,
#   'relevance': 1,
#   'analyze relevance': 1,
#   'pages': 1,
#   'web pages': 1,
#   'sources': 1,
#   'best sources': 1,
#   'good link': 1,
#   'sites': 1,
#   'link sites': 1,
#   'interactions': 4,
#   'interactions graphs': 1,
#   'proteins': 2,
#   'represent proteins': 1,
#   'edges represent': 2,
#   'represent interactions': 1,
#   'carry': 1,
#   'function': 3,
#   'biological function': 1,
#   'cell': 2,
#   'these graphs': 1,
#   'study': 1,
#   'molecular': 2,
#   'study molecular': 1,
#   'molecular interactions': 1,
#   'cellular': 1,
#   'process': 1,
#   'cellular process': 1,
#   'humans': 2,
#   '120k': 1,
#   '120k proteins': 1,
#   'millions': 1,
#   'among': 4,
#   'interactions among': 1,
#   'packet': 1,
#   'network packet': 1,
#   'packet traffic': 1,
#   'traffic graphs': 1,
#   'ip': 1,
#   'ip internet': 1,
#   'protocol': 1,
#   'internet protocol': 1,
#   'addresses': 1,
#   'protocol addresses': 1,
#   'packets': 1,
#   'flow': 3,
#   'such graphs': 3,
#   'analyzing network': 1,
#   'security': 1,
#   'network security': 1,
#   'security studying': 1,
#   'spread': 3,
#   'worms': 1,
#   'tracking': 1,
#   'criminal': 1,
#   'tracking criminal': 1,
#   'activity': 1,
#   'scene': 3,
#   'scene graphs': 2,
#   'graphics': 1,
#   'in graphics': 1,
#   'games': 2,
#   'computer games': 2,
#   'games scene': 1,
#   'logical': 1,
#   'spacial': 1,
#   'spacial relationships': 1,
#   'industry': 1,
#   'games industry': 1,
#   'element': 4,
#   'finite element': 2,
#   'meshes': 1,
#   'element meshes': 1,
#   'engineering': 1,
#   'in engineering': 1,
#   'engineering many': 1,
#   'simulations': 1,
#   'many simulations': 1,
#   'physical': 1,
#   'systems': 1,
#   'physical systems': 1,
#   'air': 1,
#   'car': 1,
#   'airplane': 1,
#   'wing': 1,
#   'airplane wing': 1,
#   'earthquakes': 1,
#   'ground': 1,
#   'structural': 1,
#   'vibrations': 1,
#   'structural vibrations': 1,
#   'building': 1,
#   'involve': 1,
#   'building involve': 1,
#   'partitioning': 1,
#   'involve partitioning': 1,
#   'space': 2,
#   'partitioning space': 1,
#   'discrete': 2,
#   'elements': 3,
#   'discrete elements': 1,
#   'the elements': 1,
#   'along': 2,
#   'elements along': 1,
#   'connections': 2,
#   'adjacent elements': 1,
#   'forms': 1,
#   'elements forms': 1,
#   'mesh': 1,
#   'element mesh': 1,
#   'robot': 2,
#   'planning': 2,
#   'robot planning': 1,
#   'states': 3,
#   'represent states': 2,
#   'possible': 1,
#   'transitions': 2,
#   'possible transitions': 1,
#   'requires': 4,
#   'this requires': 1,
#   'approximating': 1,
#   'requires approximating': 1,
#   'continuous': 1,
#   'approximating continuous': 1,
#   'motion': 1,
#   'continuous motion': 1,
#   'steps': 1,
#   'discrete steps': 1,
#   'such graph': 1,
#   'plans': 1,
#   'graph plans': 1,
#   'planning paths': 1,
#   'autonomous': 1,
#   'vehicles': 1,
#   'autonomous vehicles': 1,
#   'neural': 2,
#   'neural networks': 2,
#   'neurons': 2,
#   'represent neurons': 1,
#   'synapses': 2,
#   'brain': 2,
#   'works': 1,
#   'brain works': 1,
#   'change': 1,
#   'connections change': 1,
#   'learn': 1,
#   'human': 1,
#   'the human': 1,
#   'human brain': 1,
#   'close': 1,
#   'representing': 5,
#   'representing graphs': 5,
#   'quantum': 3,
#   'field': 1,
#   'quantum field': 1,
#   'theory': 1,
#   'field theory': 1,
#   'system': 1,
#   'quantum system': 1,
#   'the graphs': 1,
#   'analyze path': 1,
#   'integrals': 1,
#   'path integrals': 1,
#   'summing': 1,
#   'generates': 1,
#   'amplitude': 1,
#   'quantum amplitude': 1,
#   'yes': 1,
#   'amplitude yes': 1,
#   'yes i': 1,
#   'idea': 1,
#   'means': 2,
#   'semantic': 1,
#   'semantic networks': 1,
#   'words': 2,
#   'represent words': 1,
#   'concepts': 2,
#   'tionships': 1,
#   'tionships among': 1,
#   'various': 2,
#   'models': 1,
#   'various models': 1,
#   'organize': 1,
#   'humans organize': 1,
#   'knowledge': 1,
#   'machines': 1,
#   'machines might': 1,
#   'simulate': 1,
#   'might simulate': 1,
#   'organization': 1,
#   'epidemiology': 1,
#   'individuals': 1,
#   'represent individuals': 1,
#   'transfer': 1,
#   'infectious': 1,
#   'disease': 1,
#   'infectious disease': 1,
#   'individual': 1,
#   'one individual': 1,
#   'another': 2,
#   'component': 1,
#   'important component': 1,
#   'controlling': 1,
#   'diseases': 1,
#   'compilers': 3,
#   'extensively': 1,
#   'used extensively': 1,
#   'type': 1,
#   'inference': 1,
#   'type inference': 1,
#   'called data': 1,
#   'data flow': 1,
#   'analysis': 1,
#   'flow analysis': 1,
#   'register': 1,
#   'analysis register': 1,
#   'allocation': 1,
#   'register allocation': 1,
#   'purposes': 1,
#   'specialized': 1,
#   'specialized compilers': 1,
#   'query': 1,
#   'optimization': 1,
#   'query optimization': 1,
#   'database': 1,
#   'languages': 1,
#   'database languages': 1,
#   'constraint': 1,
#   'constraint graphs': 1,
#   'often used': 2,
#   'constraints': 2,
#   'represent constraints': 1,
#   'constraints among': 1,
#   'among items': 2,
#   'gsm': 1,
#   'gsm network': 1,
#   'phones': 1,
#   'cell phones': 1,
#   'consists': 1,
#   'phones consists': 1,
#   'collection': 1,
#   'overlapping': 1,
#   'overlapping cells': 1,
#   'any pair': 1,
#   'overlap': 2,
#   'must': 1,
#   'overlap must': 1,
#   'operate': 1,
#   'must operate': 1,
#   'different': 2,
#   'frequencies': 1,
#   'different frequencies': 1,
#   'these constraints': 1,
#   'modeled': 1,
#   'placed': 1,
#   'dependence': 1,
#   'dependence graphs': 1,
#   'dependences': 2,
#   'represent dependences': 1,
#   'precedences': 1,
#   'precedences among': 1,
#   'large': 1,
#   'projects': 1,
#   'large projects': 1,
#   'laying': 1,
#   'components': 2,
#   'rely': 1,
#   'components rely': 1,
#   'minimize': 1,
#   'total': 1,
#   'time': 1,
#   'total time': 1,
#   'cost': 14,
#   'completion': 1,
#   'abiding': 1,
#   'graphs how': 1,
#   'want': 3,
#   'largely': 1,
#   'graph largely': 1,
#   'depends': 1,
#   'largely depends': 1,
#   'operations': 4,
#   'intend': 1,
#   'support': 1,
#   'might want': 1,
#   'e map': 1,
#   'vertices v': 2,
#   'edges u': 1,
#   'v map': 1,
#   'return': 1,
#   'insert': 3,
#   'delete': 3,
#   'delete vertices': 1,
#   'representation figure': 1,
#   'figure an': 1,
#   'delete edges': 1,
#   'traditionally': 1,
#   'four': 1,
#   'standard': 2,
#   'four standard': 1,
#   'representations': 5,
#   'standard representations': 2,
#   'assume': 1,
#   'numbered': 1,
#   'consider': 5,
#   'consider different': 1,
#   'different representations': 1,
#   'illustrate': 1,
#   'shown': 1,
#   'graph shown': 1,
#   'represented': 1,
#   'using': 4,
#   'represented using': 1,
#   'worry': 1,
#   'associating': 1,
#   'associating data': 1,
#   'leave': 1,
#   'adjacency': 20,
#   'matrix': 3,
#   'adjacency matrix': 1,
#   'an n': 1,
#   'n matrix': 1,
#   'binary': 1,
#   'values': 1,
#   'binary values': 1,
#   'location': 1,
#   'j e': 1,
#   'symmetric': 1,
#   'diagonal': 1,
#   '1s': 1,
#   'arbitrary': 2,
#   'positions': 1,
#   'arbitrary positions': 1,
#   'main': 1,
#   'the main': 1,
#   'problem': 1,
#   'main problem': 1,
#   'matrices': 1,
#   'adjacency matrices': 1,
#   'demand': 1,
#   'space demand': 1,
#   'θ n2': 2,
#   'often sparse': 1,
#   'far': 1,
#   'fewer': 1,
#   'far fewer': 1,
#   'fewer edges': 1,
#   'list': 8,
#   'adjacency list': 3,
#   'array': 7,
#   'an array': 1,
#   'array a': 1,
#   'length n': 1,
#   'entry': 1,
#   ...},
#  'Hashmap': {'TotalCount': 1388,
#   'let': 8,
#   'quickly': 1,
#   'go': 4,
#   'quickly go': 1,
#   'hashmap': 50,
#   'simply': 1,
#   'speaking': 2,
#   'simply speaking': 1,
#   'collection': 1,
#   'object': 23,
#   'collection object': 1,
#   'uses': 3,
#   'key': 67,
#   'uses key': 1,
#   'value': 41,
#   'pairs': 2,
#   'value pairs': 1,
#   'parameters': 2,
#   'objects': 2,
#   'declared': 2,
#   'objects declared': 1,
#   'creation': 1,
#   'each key': 1,
#   'maps': 3,
#   'key maps': 2,
#   'corresponding': 1,
#   'corresponding value': 1,
#   'foo': 2,
#   'key foo': 1,
#   'foo maps': 1,
#   'bar': 2,
#   'value bar': 1,
#   'hashmap key': 1,
#   'key value': 5,
#   'consider': 2,
#   'making': 1,
#   'players': 5,
#   'football': 2,
#   'team': 1,
#   'football team': 1,
#   'identified': 1,
#   'unique': 1,
#   'number': 6,
#   'unique number': 1,
#   'would': 3,
#   'we would': 1,
#   'create': 4,
#   'would create': 1,
#   'map': 10,
#   'using': 9,
#   'integer': 15,
#   'string': 20,
#   'player': 9,
#   'name': 2,
#   'hashmap string': 8,
#   'string integer': 8,
#   'playermap': 2,
#   'integer playermap': 1,
#   'new': 10,
#   'playermap new': 1,
#   'new hashmap': 4,
#   'put': 7,
#   'integer put': 1,
#   'put players': 1,
#   'found': 1,
#   'int': 7,
#   'david': 7,
#   'int david': 1,
#   'beckham': 7,
#   'david beckham': 7,
#   'cristiano': 3,
#   'beckham cristiano': 3,
#   'ronaldo': 3,
#   'cristiano ronaldo': 3,
#   'lionel': 2,
#   'ronaldo lionel': 1,
#   'mess': 1,
#   'lionel mess': 1,
#   'neymar': 1,
#   'mess neymar': 1,
#   'return': 15,
#   'neymar return': 1,
#   'specific': 6,
#   'specific player': 1,
#   'player david': 1,
#   'beckham as': 1,
#   'note': 2,
#   'make': 2,
#   'guarantees': 1,
#   'order': 3,
#   'sorting': 1,
#   'add': 10,
#   'reason': 1,
#   'returned': 4,
#   'location': 4,
#   'even': 3,
#   'constant': 1,
#   'speed': 1,
#   'constant speed': 1,
#   'well': 1,
#   'as well': 1,
#   'hashmaps': 8,
#   'well hashmaps': 1,
#   'thread': 1,
#   'safe': 1,
#   'thread safe': 1,
#   'working': 1,
#   'environment': 1,
#   'environment consider': 1,
#   'consider using': 1,
#   'different': 5,
#   'data': 27,
#   'different data': 1,
#   'data object': 1,
#   'get': 9,
#   'later': 2,
#   'another': 1,
#   'example': 5,
#   'another example': 1,
#   'linking': 1,
#   'example linking': 1,
#   'keys': 7,
#   'linking keys': 1,
#   'subway': 1,
#   'keys subway': 1,
#   'stations': 1,
#   'subway stations': 1,
#   'values': 13,
#   'travel': 1,
#   'values travel': 1,
#   'time': 2,
#   'travel time': 1,
#   'previously': 2,
#   'time previously': 1,
#   'versions': 1,
#   'java': 8,
#   'finding': 1,
#   'java finding': 1,
#   'finding values': 1,
#   'large': 2,
#   'large hashmaps': 1,
#   'method': 26,
#   'method would': 1,
#   'worse': 1,
#   'case': 4,
#   'worse case': 1,
#   'complexity': 2,
#   'case complexity': 1,
#   'o n': 2,
#   'however': 3,
#   'since': 2,
#   'however since': 1,
#   'since java': 1,
#   'log': 1,
#   'o log': 1,
#   'log n': 1,
#   'substantial': 1,
#   'performance': 7,
#   'substantial performance': 1,
#   'improvement': 1,
#   'performance improvement': 1,
#   'structure': 5,
#   'data structure': 1,
#   'quite': 2,
#   'structure quite': 1,
#   'attractive': 1,
#   'quite attractive': 1,
#   'use': 7,
#   'creating': 5,
#   'creating different': 1,
#   'types': 1,
#   'different types': 1,
#   'hashmap you': 1,
#   'need': 2,
#   'you need': 1,
#   'import': 2,
#   'work': 2,
#   'project': 1,
#   'java project': 1,
#   'project import': 1,
#   'import let': 1,
#   'let create': 1,
#   'bunch': 1,
#   'hashmaps creating': 1,
#   'vanilla': 1,
#   'creating vanilla': 1,
#   'vanilla hashmap': 1,
#   'hashmap hashmap': 1,
#   'integer map': 1,
#   'map new': 1,
#   'integer creating': 1,
#   'creating hashmap': 2,
#   'capacity': 14,
#   'case integer': 1,
#   'integer capacity': 4,
#   'capacity hashmap': 1,
#   'integer new': 1,
#   'capacity creating': 1,
#   'load': 7,
#   'factor': 7,
#   'load factor': 7,
#   'factor integer': 1,
#   'double': 1,
#   'capacity double': 1,
#   'loadfactor': 2,
#   'double loadfactor': 1,
#   'loadfactor hashmap': 1,
#   'map3': 1,
#   'integer map3': 1,
#   'map3 new': 1,
#   'capacity loadfactor': 1,
#   'loadfactor what': 1,
#   'instantiated': 1,
#   'two': 2,
#   'two parameters': 1,
#   'affect': 1,
#   'initial': 3,
#   'performance initial': 1,
#   'initial capacity': 3,
#   'hash': 30,
#   'table': 6,
#   'hash table': 2,
#   'measures': 1,
#   'factor measures': 1,
#   'many': 2,
#   'many values': 1,
#   'allowed': 1,
#   'automatically': 2,
#   'increased': 1,
#   'automatically increased': 1,
#   'amount': 1,
#   'items': 2,
#   'greater': 1,
#   'rehashed': 1,
#   'meaning': 1,
#   'rebuilt': 1,
#   'twice': 2,
#   'buckets': 1,
#   'specified': 1,
#   'buckets specified': 1,
#   'instantiation': 2,
#   'think': 1,
#   'percentage': 1,
#   'capacity percentage': 1,
#   'cause': 1,
#   'expand': 1,
#   'automatically expand': 1,
#   'expand and': 1,
#   'ever': 1,
#   'want': 9,
#   'ever want': 1,
#   'know': 3,
#   'bucket': 4,
#   'hash bucket': 1,
#   'lives': 1,
#   'value lives': 1,
#   'find': 2,
#   'printing': 2,
#   'printing all': 1,
#   'all values': 1,
#   'values in': 1,
#   'in the': 1,
#   'the map': 1,
#   'entryset': 9,
#   'map entryset': 1,
#   'keyset': 4,
#   'entryset keyset': 1,
#   'keyset there': 1,
#   'primary': 1,
#   'two primary': 1,
#   'methods': 3,
#   'primary methods': 1,
#   'loop': 6,
#   'hashmap entryset': 1,
#   'when using': 1,
#   'returning': 2,
#   'set': 3,
#   'key objects': 1,
#   'remember': 3,
#   'able': 2,
#   'wanted': 2,
#   'playernumber': 1,
#   'using playernumber': 1,
#   'list': 17,
#   'getting': 3,
#   'easy': 1,
#   'print': 2,
#   'players using': 2,
#   'integer key': 1,
#   'key key': 2,
#   'results': 2,
#   'key results': 1,
#   'results david': 2,
#   'ronaldo by': 1,
#   'calling': 1,
#   'by calling': 1,
#   'calling entryset': 1,
#   'entry': 27,
#   'entry object': 13,
#   'stores': 4,
#   'information': 1,
#   'stores information': 1,
#   'easily': 1,
#   'looped': 1,
#   'looping': 3,
#   'faster': 2,
#   'going': 1,
#   'asking': 1,
#   'key twice': 1,
#   'notice': 1,
#   'used': 10,
#   'call': 2,
#   'getkey': 1,
#   'call getkey': 1,
#   'getvalue': 1,
#   'also': 1,
#   'also entryset': 1,
#   'implementations': 1,
#   'entryset implementations': 1,
#   'usually': 1,
#   'implementations usually': 1,
#   'implement': 1,
#   'usually implement': 1,
#   'tostring': 1,
#   'tostring method': 1,
#   'saves': 1,
#   'console': 1,
#   'entry integer': 2,
#   'integer string': 2,
#   'string entry': 2,
#   'entry results': 1,
#   'one': 8,
#   'generally': 1,
#   'generally speaking': 1,
#   'speaking using': 1,
#   'better': 1,
#   'practice': 1,
#   'better practice': 1,
#   'less': 1,
#   'overhead': 1,
#   'less overhead': 1,
#   'adding': 6,
#   'adding pairs': 1,
#   'hashmap if': 1,
#   'if not': 1,
#   'present': 6,
# ...
#   'last one': 1,
#   'tried': 1,
#   'one tried': 1,
#   'tried enqueue': 1,
#   'choices onto': 1,
#   'return': 1,
#   'queue return': 1,
#   'return we': 1,
#   'later': 1,
#   'techniques later': 1,
#   'course': 1,
#   'arithmetic': 3,
#   'expression': 8,
#   'arithmetic expression': 2,
#   'evaluation': 1,
#   'expression evaluation': 1,
#   'evaluation an': 1,
#   'important': 1,
#   'an important': 1,
#   'important application': 1,
#   'parsing': 3,
#   'for example': 1,
#   'compiler must': 1,
#   'parse': 3,
#   'must parse': 1,
#   'parse arithmetic': 1,
#   'expressions': 3,
#   'arithmetic expressions': 1,
#   'written': 2,
#   'expressions written': 1,
#   'written using': 1,
#   'infix': 8,
#   'using infix': 1,
#   'notation': 3,
#   'infix notation': 2,
#   'notation we': 1,
#   'break': 1,
#   'we break': 1,
#   'problem': 2,
#   'parsing infix': 2,
#   'infix expressions': 1,
#   'stages': 1,
#   'two stages': 1,
#   'first': 1,
#   'convert': 2,
#   'different': 1,
#   'representation': 1,
#   'different representation': 1,
#   'representation called': 1,
#   'postfix': 9,
#   'called postfix': 1,
#   'postfix expression': 4,
#   'somewhat': 1,
#   'easier': 1,
#   'somewhat easier': 1,
#   'easier problem': 1,
#   'directly': 1,
#   'directly parsing': 1,
#   'converting': 1,
#   'typically': 1,
#   'deal': 1,
#   'operators': 3,
#   'operands': 5,
#   'writing': 2,
#   'gives': 2,
#   'operands gives': 2,
#   'called operands': 1,
#   'called infix': 1,
#   'since': 1,
#   'infix since': 1,
#   'the expression': 1,
#   'expression writing': 1,
#   'prefix': 1,
#   'prefix expression': 1,
#   'suppose': 1,
#   'expression suppose': 1,
#   'want': 1,
#   'compute': 1,
#   'cost': 1,
#   'shopping': 1,
#   'trip': 1,
#   'shopping trip': 1,
#   'numbers': 1,
#   'multiply': 1,
#   'sales': 1,
#   'local sales': 1,
#   'tax': 1,
#   'sales tax': 1,
#   'depending': 1,
#   'tax depending': 1,
#   'calculator': 1,
#   'answer': 1,
#   'would': 1,
#   'answer would': 1,
#   'avoid': 1,
#   'to avoid': 1,
#   'confusion': 1,
#   'postfix notation': 1,
#   'notation postfix': 1,
#   'nice': 1,
#   'property': 1,
#   'nice property': 1,
#   'parentheses': 3,
#   'unnecessary': 1,
#   'describe': 2,
#   'read': 2,
#   'tokens': 3,
#   'tokens one': 1,
#   'time if': 1,
#   'token': 5,
#   'integer': 2,
#   'write': 1,
#   'integer write': 1,
#   'output': 1,
#   'output if': 1,
#   'operator push': 1,
#   'entries': 2,
#   'pop entries': 2,
#   'higher': 1,
#   'equal': 1,
#   'priority': 1,
#   'equal priority': 1,
#   'left parentheses': 1,
#   'parentheses push': 1,
#   'stack if': 2,
#   'right parentheses': 1,
#   'meet': 1,
#   'finish': 1,
#   'reading': 1,
#   'finish reading': 1,
#   'string': 1,
#   'evaluating': 1,
#   'we describe': 1,
#   'evaluate': 1,
#   'we read': 1,
#   'integer push': 1,
#   'binary': 1,
#   'binary operator': 1,
#   'operator pop': 1,
#   'top two': 1,
#   'two elements': 1,
#   'apply': 1,
#   'stack apply': 1,
#   'result': 1,
#   'result back': 1},
#  'test': {'TotalCount': 12,
#   'define': 1,
#   'stack': 1,
#   'define stack': 1,
#   'insertion': 2,
#   'sort': 3,
#   'insertion sort': 2,
#   'merge': 1,
#   'merge sort': 1,
#   'directed': 1,
#   'graph': 2,
#   'directed graph': 1,
#   'undirected': 1,
#   'undirected graph': 1},
#  'Trees': {'TotalCount': 1504,
#   'start': 8,
#   'learning': 2,
#   'start learning': 1,
#   'trees': 9,
#   'graphs': 2,
#   'get': 3,
#   'really': 2,
#   'get really': 1,
#   'confusing': 1,
#   'really confusing': 1,
#   'store': 3,
#   'data': 16,
#   'store data': 3,
#   'linear': 3,
#   'way': 6,
#   'linear way': 2,
#   'both data': 1,
#   'structures': 4,
#   'data structures': 3,
#   'structures store': 1,
#   'specific': 3,
#   'specific way': 1,
#   'post': 2,
#   'this post': 1,
#   'help': 2,
#   'better': 3,
#   'understand': 3,
#   'better understand': 1,
#   'tree': 54,
#   'tree data': 4,
#   'structure': 8,
#   'data structure': 6,
#   'clarify': 1,
#   'confusion': 1,
#   'may': 3,
#   'article': 1,
#   'learn': 1,
#   'learn what': 1,
#   'examples': 2,
#   'tree examples': 1,
#   'trees its': 1,
#   'terminology': 2,
#   'its terminology': 1,
#   'works': 4,
#   'works how': 1,
#   'implement': 5,
#   'implement tree': 1,
#   'tree structures': 1,
#   'code': 16,
#   'let': 29,
#   'journey': 1,
#   'learning journey': 1,
#   'definition': 2,
#   'definition when': 1,
#   'starting': 2,
#   'when starting': 1,
#   'programming': 1,
#   'common': 1,
#   'understand better': 1,
#   'linear data': 1,
#   'like': 2,
#   'structures like': 1,
#   'like trees': 1,
#   'organize': 2,
#   'they organize': 1,
#   'organize data': 1,
#   'hierarchically': 2,
#   'data hierarchically': 1,
#   'dive': 2,
#   'real': 2,
#   'life': 1,
#   'real life': 1,
#   'life examples': 1,
#   'mean': 1,
#   'i mean': 1,
#   'say': 4,
#   'i say': 1,
#   'hierarchical': 1,
#   'hierarchical way': 1,
#   'imagine': 4,
#   'family': 4,
#   'family tree': 3,
#   'relationships': 1,
#   'generation': 1,
#   'grandparents': 2,
#   'generation grandparents': 1,
#   'parents': 3,
#   'grandparents parents': 1,
#   'children': 22,
#   'parents children': 1,
#   'siblings': 1,
#   'children siblings': 1,
#   'etc': 2,
#   'siblings etc': 1,
#   'commonly': 1,
#   'we commonly': 1,
#   'commonly organize': 1,
#   'organize family': 1,
#   'family trees': 1,
#   'trees hierarchically': 1,
#   'my family': 1,
#   'tree the': 2,
#   'drawing': 1,
#   'tossico': 1,
#   'akikazu': 1,
#   'tossico akikazu': 1,
#   'hitomi': 1,
#   'akikazu hitomi': 1,
#   'takemi': 1,
#   'toshiaki': 1,
#   'juliana': 1,
#   'tk': 1,
#   'yuji': 1,
#   'tk yuji': 1,
#   'bruno': 1,
#   'yuji bruno': 1,
#   'kaio': 1,
#   'brothers': 1,
#   'organization': 1,
#   'an organization': 1,
#   'another': 3,
#   'example': 11,
#   'another example': 1,
#   'hierarchy': 2,
#   'company': 1,
#   'a company': 1,
#   'hierarchy in': 1,
#   'html': 2,
#   'in html': 1,
#   'document': 2,
#   'object': 3,
#   'document object': 2,
#   'model': 2,
#   'object model': 2,
#   'dom': 2,
#   'model dom': 2,
#   'dom works': 1,
#   'dom the': 1,
#   'the html': 1,
#   'tag': 5,
#   'html tag': 1,
#   'contains': 3,
#   'tag contains': 1,
#   'tags': 3,
#   'head': 2,
#   'head tag': 2,
#   'body': 2,
#   'body tag': 2,
#   'those tags': 1,
#   'tags contains': 1,
#   'contains specific': 1,
#   'elements': 2,
#   'specific elements': 1,
#   'the head': 1,
#   'meta': 1,
#   'title': 1,
#   'title tags': 1,
#   'the body': 1,
#   'show': 2,
#   'user': 1,
#   'interface': 1,
#   'user interface': 1,
#   'h1': 1,
#   'example h1': 1,
#   'li': 1,
#   'li etc': 1,
#   'technical': 1,
#   'a technical': 1,
#   'technical definition': 1,
#   'definition a': 1,
#   'a tree': 1,
#   'collection': 2,
#   'entities': 1,
#   'called': 5,
#   'entities called': 1,
#   'nodes': 21,
#   'called nodes': 1,
#   'connected': 4,
#   'edges': 2,
#   'node': 133,
#   'each node': 2,
#   'node contains': 1,
#   'value': 56,
#   'child': 94,
#   'child node': 7,
#   'first': 10,
#   'the first': 3,
#   'first node': 2,
#   'root': 21,
#   'root node': 8,
#   'another node': 1,
#   'parent': 21,
#   'parent node': 2,
#   'connected node': 1,
#   'all tree': 1,
#   'tree nodes': 1,
#   'links': 1,
#   'links called': 1,
#   'called edges': 1,
#   'important': 5,
#   'part': 4,
#   'important part': 1,
#   'manages': 1,
#   'relationship': 1,
#   'leaves': 2,
#   'last': 3,
#   'last nodes': 1,
#   'without': 1,
#   'nodes without': 1,
#   'without children': 1,
#   'like real': 1,
#   'real trees': 1,
#   'branches': 1,
#   'root branches': 1,
#   'finally': 2,
#   'other important': 1,
#   'concepts': 1,
#   'important concepts': 1,
#   'height': 3,
#   'depth': 5,
#   'the height': 1,
#   'length': 4,
#   'longest': 2,
#   'path': 6,
#   'longest path': 2,
#   'leaf': 6,
#   'the depth': 1,
#   'summary': 1,
#   'terminology summary': 1,
#   'summary root': 1,
#   'topmost': 1,
#   'topmost node': 1,
#   'edge': 2,
#   'tree edge': 1,
#   'link': 1,
#   'two': 6,
#   'two nodes': 1,
#   'nodes child': 1,
#   'node parent': 1,
#   'node leaf': 1,
#   'tree height': 1,
#   'leaf depth': 1,
#   'binary': 20,
#   'root binary': 1,
#   'binary trees': 2,
#   'trees now': 1,
#   'discuss': 2,
#   'type': 3,
#   'specific type': 1,
#   'call': 2,
#   'we call': 1,
#   'thebinary': 1,
#   'thebinary tree': 1,
#   'computer': 1,
#   'in computer': 1,
#   'science': 1,
#   'computer science': 1,
#   'binary tree': 8,
#   'two children': 4,
#   'referred': 1,
#   'left': 60,
#   'left child': 41,
#   'right': 46,
#   'wikipedia': 4,
#   'right wikipedia': 1,
#   'wikipedia so': 2,
#   'so let': 2,
#   'look': 5,
#   'thing': 3,
#   'first thing': 2,
#   'need': 8,
#   'keep': 1,
#   'mind': 1,
#   'three': 3,
#   'attributes': 2,
#   'three attributes': 2,
#   'attributes value': 2,
#   'simple': 2,
#   'simple binary': 1,
#   'initializes': 1,
#   'properties': 1,
#   'three properties': 1,
#   'take': 3,
#   'our binary': 1,
#   'class': 1,
#   'tree class': 1,
#   'instantiate': 1,
#   'pass': 2,
#   'parameter': 1,
#   'set': 9,
#   'none': 5,
#   'create': 6,
#   'node data': 1,
#   'test': 7,
#   'string': 1,
#   'tree node': 1,
#   'print': 19,
#   'see': 2,
#   'values': 9,
#   'go': 19,
#   'insertion': 5,
#   'insertion part': 1,
#   'method': 7,
#   'insert': 13,
#   'new': 15,
#   'new node': 10,
#   'rules': 2,
#   'rules if': 1,
#   'current': 20,
#   'current node': 15,
#   'nodeand': 1,
#   'new nodeand': 1,
#   'nodeand set': 1,
#   'put': 4,
#   'current left': 2,
#   'place': 3,
#   'allocate': 2,
#   'draw': 1,
#   'code again': 1,
#   'else': 3,
#   'or else': 1,
#   'right child': 31,
#   'done': 5,
#   'entirely': 1,
#   'still': 1,
#   'we still': 1,
#   'still need': 1,
#   'build': 2,
#   'followingtree': 1,
#   'followingtree to': 1,
#   'summarize': 1,
#   'to summarize': 1,
#   'illustration': 2,
#   'b node': 2,
#   'c node': 1,
#   'node b': 2,
#   'b right': 1,
#   'child c': 1,
#   'c left': 1,
#   'e node': 1,
#   'node c': 1,
#   'c right': 1,
#   'f node': 1,
#   'f nodes': 1,
#   'children so': 1,
#   'tree insertion': 2,
#   'think': 2,
#   'traversal': 4,
#   'tree traversal': 2,
#   'options': 1,
#   'two options': 1,
#   'search': 19,
#   'dfs': 6,
#   'search dfs': 2,
#   'bfs': 5,
#   'search bfs': 2,
#   'algorithm': 19,
#   'traversing': 2,
#   'searching': 3,
#   'searching tree': 2,
#   'one': 9,
#   'starts': 2,
#   'one starts': 1,
#   'explores': 3,
#   'far': 1,
#   'possible': 1,
#   'along': 1,
#   'possible along': 1,
#   'branch': 1,
#   'wikipedia bfs': 1,
#   'it starts': 1,
#   'tree root': 1,
#   'neighbor': 1,
#   'neighbor nodes': 1,
#   'nodes first': 1,
#   'moving': 1,
#   'next': 1,
#   'level': 7,
#   'next level': 1,
#   'level wikipedia': 1,
#   'traversal type': 1,
#   'dfs dfs': 1,
#   'dfs explores': 1,
#   'backtracking': 1,
#   'exploring': 1,
#   'exploring another': 1,
#   'another path': 1,
#   'result': 4,
#   'the result': 3,
#   'break': 3,
#   'then go': 1,
#   'this node': 4,
#   'backtrack': 6,
#   'deep': 1,
#   'go deep': 1,
#   'called dfs': 1,
#   'dfs algorithm': 1,
#   'familiar': 1,
#   'traversal algorithm': 1,
#   'types': 1,
#   'discuss types': 1,
#   'exactly': 1,
#   'tree example': 2,
#   'the left': 2,
#   'left first': 2,
#   'middle': 2,
#   'second': 3,
#   'middle second': 1,
#   'right last': 1,
#   'now let': 6,
#   'value go': 1,
#   'order': 3,
#   'post order': 1,
#   'order algorithm': 1,
#   'right second': 1,
#   'middle last': 1,
#   'value search': 1,
#   'bfs bfs': 1,
#   'bfs algorithm': 2,
#   'traverses': 1,
#   'algorithm traverses': 1,
#   'tree level': 1,
#   'helps': 1,
#   'explain': 1,
#   'better explain': 1,
#   'algorithm so': 1,
#   'traverse': 1,
#   'traverse level': 1,
#   'value nodes': 1,
#   'to implement': 1,
#   'use': 7,
#   'queue': 5,
#   'queue data': 1,
#   'work': 1,
#   'explanation': 1,
#   'add': 3,
#   'first add': 1,
#   'put method': 1,
#   'iterate': 1,
#   'empty': 2,
#   'right children': 2,
#   'nodehas': 1,
#   'current nodehas': 1,
#   'nodehas children': 1,
#   'node level': 1,
#   'queuehelper': 1,
#   'binary search': 10,
#   'search tree': 9,
#   'tree a': 1,
#   'a binary': 1,
#   'sometimes': 1,
#   'sometimes called': 1,
#   'ordered': 1,
#   'called ordered': 1,
#   'sorted': 2,
#   'sorted binary': 1,
#   'keeps': 1,
#   'sorted order': 1,
#   'lookup': 1,
#   'operations': 1,
#   'principle': 1,
#   'search wikipedia': 1,
#   'wikipedia an': 1,
#   'an important': 2,
#   'property': 2,
#   'important property': 1,
#   'nodeis': 1,
#   'tree nodeis': 1,
#   'larger': 1,
#   'nodeis larger': 1,
#   'offspring': 2,
#   'smaller': 14,
#   'right here': 1,
#   'breakdown': 1,
#   'illustration a': 1,
#   'inverted': 1,
#   'subtree': 11,
#   'the subtree': 1,
#   'needs': 5,
#   'subtree needs': 2,
#   'side': 10,
#   'right side': 4,
#   'correct': 1,
#   'option': 1,
#   'correct option': 1,
#   'satisfies': 1,
#   'it satisfies': 1,
#   'tree property': 1,
#   'problem': 1,
#   'one problem': 1,
#   'it needs': 1,
#   'left side': 6,
#   'time': 2,
#   'insert new': 1,
#   'new nodes': 4,
#   'nodes search': 1,
#   'delete': 3,
#   'value delete': 1,
#   'delete nodes': 1,
#   'balance': 1,
#   'adding': 1,
#   'insertion adding': 1,
#   'adding new': 1,
#   'tree imagine': 1,
#   'empty tree': 1,
#   'want': 5,
#   'add new': 1,
#   'following': 2,
#   'following values': 1,
#   'know': 2,
#   'inserting': 2,
#   'start inserting': 1,
#   'inserting node': 1,
#   'greater': 11,
#   'since': 5,
#   'notice': 1,
#   'pattern': 1,
#   'node value': 4,
#   'value greater': 2,
#   'node go': 2,
#   'right subtree': 4,
#   'child insert': 2,
#   'else backtrack': 2,
#   'step': 2,
#   'left subtree': 4,
#   'handle': 3,
#   'special': 1,
#   'handle special': 1,
#   'cases': 2,
#   'special cases': 1,
#   'equal': 3,
#   'current value': 1,
#   'node use': 1,
#   'rule': 4,
#   'use rule': 1,
#   'number': 2,
#   'rule number': 1,
#   'consider': 1,
#   'consider inserting': 1,
#   'inserting equal': 1,
#   'equal values': 1,
#   'seems': 1,
#   'it seems': 1,
#   'powerful': 1,
#   'the powerful': 1,
#   'powerful part': 1,
#   'recursion': 1,
#   'recursion part': 1,
#   'line': 21,
#   'lines': 5,
#   'both lines': 1,
#   'code call': 1,
#   'respectively': 1,
#   'children respectively': 1,
#   'ones': 1,
#   'node or': 1,
#   'or the': 1,
#   'the algorithm': 2,
#   'searches': 1,
#   'given': 7,
#   'given value': 6,
#   'integer': 1,
#   'value integer': 1,
#   'integer number': 1,
#   'item': 1,
#   'important item': 1,
#   'note': 3,
#   'defined': 1,
#   'insertion algorithm': 1,
#   'subtree nodes': 2,
#   'smaller values': 1,
#   'values greater': 1,
#   'based': 1,
#   'node based': 1,
#   'we start': 3,
#   'value smaller': 1,
#   'yes': 2,
#   'if yes': 2,
#   'if rules': 1,
#   'false': 2,
#   'compare': 1,
#   'comparison': 1,
#   'returns': 2,
#   'comparison returns': 1,
#   'true': 4,
#   'returns true': 2,
#   'yeah': 3,
#   'say yeah': 1,
#   'our tree': 1,
#   'otherwise': 2,
#   'value otherwise': 1,
#   'nooo': 1,
#   'say nooo': 1,
#   'beak': 1,
#   'code lines': 1,
#   'fall': 2,
#   'falls': 1,
#   'line falls': 1,
#   'initializing': 1,
#   'many': 1,
#   'insert many': 1,
#   'many new': 1,
#   'inserted': 1,
#   'inserted node': 1,
#   'method really': 1,
#   'really works': 1,
#   'given values': 1,
#   'exist': 1,
#   'oh': 1,
#   'oh yeah': 1,
#   'our search': 1,
#   'deletion': 2,
#   'removing': 2,
#   'deletion removing': 1,
#   'organizing': 1,
#   'organizing deletion': 1,
#   'complex': 1,
#   'complex algorithm': 1,
#   'different': 1,
#   'handle different': 1,
#   'different cases': 1,
#   'remove': 8,
#   'scenarios': 1,
#   'following scenarios': 1,
#   'single': 1,
#   'single child': 1,
#   'scenario': 3,
#   'scenario a': 3,
#   'a node': 3,
#   'children leaf': 1,
#   'leaf node': 1,
#   'simply': 1,
#   'simply delete': 1,
#   'reorganize': 1,
#   'one child': 6,
#   'child left': 3,
#   'case': 2,
#   'algorithm needs': 1,
#   'make': 3,
#   'point': 3,
#   'node point': 1,
#   'child point': 2,
#   'find': 4,
#   'minimum': 2,
#   'minimum value': 2,
#   'value starting': 1,
#   'sright': 1,
#   'node sright': 1,
#   'sright child': 1,
#   'first note': 1,
#   'parameters': 1,
#   'parameters value': 1,
#   'we want': 1,
#   'nodethat': 1,
#   'removal': 1,
#   'second note': 1,
#   'returning': 1,
#   'returning value': 1,
#   'our algorithm': 1,
#   'return': 4,
#   'boolean': 1,
#   'boolean value': 1,
#   'it returns': 1,
#   'finds': 1,
#   'removes': 1,
#   'return false': 1,
#   'from line': 8,
#   'line we': 8,
#   'start searching': 1,
#   'valuethat': 1,
#   'looking': 2,
#   'nodevalue': 1,
#   'current nodevalue': 1,
#   'recursively': 2,
#   'subtree recursively': 2,
#   'greater go': 1,
#   'remove algorithm': 1,
#   'cover': 7,
#   'we cover': 7,
#   'we remove': 2,
#   'setting': 2,
#   'clear': 1,
#   'clear node': 1,
#   'node method': 1,
#   'method i': 1,
#   'sets': 1,
#   'it sets': 1,
#   'nodes left': 1,
#   'child right': 3,
#   'we set': 4,
#   'parent left': 2,
#   'parent right': 2,
#   'rightchildren': 1,
#   'we get': 1,
#   'smallest': 3,
#   'smallest value': 1,
#   'shown': 1,
#   'finish': 1,
#   'smallest node': 1,
#   'line if': 1,
#   'return true': 2,
#   'to use': 2,
#   'method set': 1,
#   'none value': 1,
#   'method go': 1,
#   'go way': 1,
#   'anymore': 1,
#   'find anymore': 1,
#   'anymore nodes': 1,
#   'found': 1,
#   'smallest one': 1}}
